# %%
## 🧪 Lab Task: Data Collection from RemoteOK

#As a data scientist, the first step in any project is to collect relevant and structured data. In this exercise, your task is to extract job-related information from the RemoteOK job website: [https://remoteok.com/r](https://remoteok.com/r).

### 🎯 Objectives:
#- Collect the following data fields for each job posting:
 # - **Company Name**
  #- **Job Role**
  #- **Location**
  #- **Features or Tags** (e.g., technologies, benefits, job type)

### 🛠 Instructions:
#- Use Python along with libraries such as `requests`, `pandas`, and optionally `json` or `BeautifulSoup` if needed.
#- Retrieve the job data from the RemoteOK API or web page.
#- Parse the JSON or HTML response to extract the required fields.
#- Store the collected data in a structured format such as **CSV** for future analysis.

### 📦 Output:
#A CSV file (e.g., `remoteok_jobs.csv`) containing all extracted job listings with the specified fields.

#> ✅ This dataset will serve as the foundation for further data analysis and machine learning tasks in upcoming lab exercises.

# %%
# To run this script, you need to install the following libraries:
# pip install requests pandas

import requests
import pandas as pd

def scrape_remoteok_jobs():
    """
    Scrapes job listings from the RemoteOK API.
    Extracts company name, job role, location, and tags/features.
    """
    print("--- Starting RemoteOK Job Scraping ---")
    api_url = "https://remoteok.com/api"

    try:
        # Fetch JSON data from the API
        response = requests.get(api_url, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()

        jobs_data = response.json()

        # The first element is metadata, so skip it
        jobs_list = []

        for idx, job in enumerate(jobs_data[1:], start=1):
            job_entry = {
                "Company Name": job.get("company", "N/A"),
                "Job Role": job.get("position", "N/A"),
                "Location": job.get("location", "Worldwide"),
                "Tags/Features": ", ".join(job.get("tags", []))
            }
            jobs_list.append(job_entry)

            # Print to console
            print(f"\nJob #{idx}")
            print(f"Company Name : {job_entry['Company Name']}")
            print(f"Job Role     : {job_entry['Job Role']}")
            print(f"Location     : {job_entry['Location']}")
            print(f"Tags/Features: {job_entry['Tags/Features']}")

        print(f"\n Successfully scraped {len(jobs_list)} job postings.")
        return jobs_list

    except requests.exceptions.RequestException as e:
        print(f" Error fetching data from RemoteOK API: {e}")
        return None
    except Exception as e:
        print(f" Error processing job data: {e}")
        return None

def save_to_csv(data, filename):
    """
    Saves scraped job data to a CSV file.
    """
    if not data:
        print(f"No data to save to {filename}. Skipping.")
        return

    try:
        df = pd.DataFrame(data)
        df.to_csv(filename, index=False, encoding='utf-8')
        print(f"\n Data successfully saved to {filename}")
    except IOError as e:
        print(f" Error saving to CSV: {e}")

# --- Main Execution ---
if __name__ == "__main__":
    jobs_data = scrape_remoteok_jobs()

    if jobs_data:
        save_to_csv(jobs_data, "remoteok_jobs.csv")

    print("\n--- Process Complete ---")
# Out:
# --- Starting RemoteOK Job Scraping ---
#
# Job #1
# Company Name : Bonfire Studios
# Job Role     : Character Concept Artist
# Location     : United States
# Tags/Features: 3d, support, recruiting
#
# Job #2
# Company Name : Coins.ph
# Job Role     : Strategy Manager
# Location     : Taguig City, Metro Manila, Philippines
# Tags/Features: manager, web3, crypto, cryptocurrencies, support, growth, financial, finance, mobile, strategy, management, operational
#
# Job #3
# Company Name : Aragon
# Job Role     : Content &amp; Social Lead
# Location     : Remote - Anywhere
# Tags/Features: web3, full-stack, technical, support, software, growth, manager, seo, strategy, management, lead, content, marketing
#
# Job #4
# Company Name : The Biz Conquest
# Job Role     : Mobile Developer
# Location     :
# Tags/Features: dev, engineer, mobiledev, react native
#
# Job #5
# Company Name : Virta Health
# Job Role     : Backend Software Engineer Client Group
# Location     :
# Tags/Features: software, frontend, security, training, full-stack, technical, support, code, cloud, operational, golang, medical, health, engineer, engineering, backend
#
# Job #6
# Company Name : Deblock
# Job Role     : Senior Backend Engineer
# Location     :
# Tags/Features: golang, crypto, fintech, banking, senior, engineer, backend
#
# Job #7
# Company Name : CrowdGen by Appen
# Job Role     : Payment QR Code from Eye AI
# Location     : India
# Tags/Features: code, qa, mobile
#
# Job #8
# Company Name : Machinify
# Job Role     : Automation Engineer UI Quality Assurance
# Location     : Palo Alto
# Tags/Features: ui, design, front-end, frontend, docker, software, testing, test, web, qa, healthcare, recruiting, engineer, digital nomad
#
# Job #9
# Company Name : Arbitrum Foundation
# Job Role     : Developer Relations Engineer
# Location     : Europe
# Tags/Features: developer, web3, cryptocurrency, ethereum, security, technical, growth, code, education, finance, content, health, healthcare, engineer, engineering, recruitment, educational, full-time, digital nomad
#
# Job #10
# Company Name : Koala Health
# Job Role     : Customer Experience Associate
# Location     : Remote
# Tags/Features: technical, support, web, voice, medical, health, healthcare
#
# Job #11
# Company Name : CoinGecko
# Job Role     : Human Resources Associate Mid level
# Location     :
# Tags/Features: cryptocurrency, hr, system, training, technical, support, payroll, financial, education, leader, management, operations, operational
#
# Job #12
# Company Name : Prophet Security
# Job Role     : Backend Software Engineer
# Location     :
# Tags/Features: golang, infosec, software, security, engineer, backend
#
# Job #13
# Company Name : lakeFS
# Job Role     : Senior Software Engineer
# Location     :
# Tags/Features: golang, software, senior, engineer
#
# Job #14
# Company Name : Tolt
# Job Role     : Product Engineer
# Location     :
# Tags/Features: javascript, typescript, react, product, aws, engineer
#
# Job #15
# Company Name : Included Health
# Job Role     : Connected Care Assistant
# Location     : Remote
# Tags/Features: assistant, training, recruiter, support, management, medical, health, healthcare, full-time, non tech
#
# Job #16
# Company Name : GoodLeap
# Job Role     : Customer Care Advisor
# Location     : Remote
# Tags/Features: supervisor, support, developer, software, management, sales, reliability, digital nomad
#
# Job #17
# Company Name : Monzo
# Job Role     : Senior Backend Engineer
# Location     :
# Tags/Features: golang, senior, engineer, backend
#
# Job #18
# Company Name : Executive Bootcamp
# Job Role     : $2.000+ monthly LinkedIn DM reply Job USA TIMEZONE
# Location     :
# Tags/Features: sales, marketing, other
#
# Job #19
# Company Name : InfStones
# Job Role     : DevOps Engineer
# Location     : Texas
# Tags/Features: amazon, web3, system, security, support, software, testing, test, code, qa, devops, serverless, cloud, git, node, administrator, management, reliability, engineer, linux, full-time
#
# Job #20
# Company Name : Peach Finance
# Job Role     : Technical Writer
# Location     : Remote
# Tags/Features: system, training, technical, writer, developer, financial, video, finance, api, management, content, senior, marketing, digital nomad
#
# Job #21
# Company Name : FetLife
# Job Role     : Senior Full Stack Engineer
# Location     :
# Tags/Features: engineer, ruby, vue, redis, rust, kubernetes, work from home, remote, terraform, google cloud, senior, dev, javascript, backend, front end, full time, full stack, sql, postgres, elasticsearch, typescript
#
# Job #22
# Company Name : CloudWalk
# Job Role     : Customer Support Engineer I Intern
# Location     : Remote
# Tags/Features: technical, support, voice, fintech, ruby, engineer, engineering
#
# Job #23
# Company Name : CoinGecko
# Job Role     : Account Executive
# Location     :
# Tags/Features: saas, web3, cryptocurrency, training, technical, support, growth, financial, education, fintech, api, leader, strategy, management, senior, operations, operational, marketing, sales, executive
#
# Job #24
# Company Name :
# Job Role     :
# Location     : Remote
# Tags/Features:
#
# Job #25
# Company Name : Accompany Health
# Job Role     : Medical Record Specialist
# Location     : United States
# Tags/Features: education, lead, go, medical, health, healthcare, full-time, non tech
#
# Job #26
# Company Name : CertiK
# Job Role     : Blockchain Security Expert AI Track
# Location     : US / Remote
# Tags/Features: security, web3, support, software, sales, engineering, full-time
#
# Job #27
# Company Name : Anchorage Digital
# Job Role     : Growth Marketing Lead
# Location     : United States
# Tags/Features: growth, crypto, security, testing, financial, finance, bank, leader, management, lead, marketing, analytics, legal, engineering
#
# Job #28
# Company Name : Mozilla Corporation
# Job Role     : Senior Backend Engineer
# Location     :
# Tags/Features: golang, senior, engineer, backend
#
# Job #29
# Company Name : Nomi Health
# Job Role     : Data Engineer
# Location     : Austin, Texas
# Tags/Features: technical, testing, nosql, medical, engineer, engineering
#
# Job #30
# Company Name : WEP Clinical
# Job Role     : Associate Director Clinical Monitoring
# Location     : Remote, US
# Tags/Features: director, training, support, growth, travel, management, lead, senior
#
# Job #31
# Company Name : One Medical
# Job Role     : Social Programs Manager
# Location     : Houston, TX
# Tags/Features: manager
#
# Job #32
# Company Name : CloudWalk
# Job Role     : Chargeback Analyst
# Location     : SÃ£o Paulo
# Tags/Features: analyst, teach, support, code, fintech, operations, operational, engineering
#
# Job #33
# Company Name : CEF.Ai
# Job Role     : Principal Software Engineer
# Location     :
# Tags/Features: other, dev
#
# Job #34
# Company Name :
# Job Role     :
# Location     :
# Tags/Features:
#
# Job #35
# Company Name : Welo Data
# Job Role     : Korean Japanese Lyric Transliteration Reviewer
# Location     :
# Tags/Features: quality assurance, teaching, part time, remote, freelance, japanese, korean, reviewer, translation
#
# Job #36
# Company Name : Socure
# Job Role     : Staff Software Engineer Backend
# Location     : Carson City
# Tags/Features: software, design, graphql, system, support, fintech, elasticsearch, lead, analytics, engineer, engineering, apache, backend, digital nomad
#
# Job #37
# Company Name : Inkitt
# Job Role     : Senior DevOps Engineer
# Location     : Remote Mexico City
# Tags/Features: redis, system, security, support, devops, elasticsearch, c, cloud, postgresql, senior, analytics, reliability, engineer, backend
#
# Job #38
# Company Name : Sticker Mule
# Job Role     : Software engineer
# Location     :
# Tags/Features: engineer, dev, postgres, docker, redis, kubernetes, gcp
#
# Job #39
# Company Name : Coins.ph
# Job Role     : KYC Ops Leader
# Location     : Taguig City, Metro Manila, Philippines
# Tags/Features: crypto, cryptocurrencies, training, growth, financial, fintech, mobile, leader, strategy, management, lead, operations, operational
#
# Job #40
# Company Name : Tala
# Job Role     : Senior Android Engineer
# Location     : Remote-India
# Tags/Features: crypto, financial, fintech, management, senior, android, engineer
#
# Job #41
# Company Name : Aprio
# Job Role     : Aprio Canada National Tax Office Leader Senior Tax Director
# Location     : Toronto
# Tags/Features: director, training, technical, support, growth, leader, management, lead, senior, executive
#
# Job #42
# Company Name : Sayari
# Job Role     : Associate Data Engineer
# Location     : United States
# Tags/Features: python, training, software, growth, financial, cloud, engineer, engineering, apache
#
# Job #43
# Company Name : CloudWalk
# Job Role     : Paid Media Data Analyst
# Location     : Brasilia
# Tags/Features: analyst, technical, growth, financial, investment, fintech, strategy, marketing, analytics, engineering, executive
#
# Job #44
# Company Name : Allocate
# Job Role     : Senior Software Engineer Backend
# Location     : California
# Tags/Features: software, design, c#, docker, technical, support, developer, code, web, fintech, git, api, strategy, senior, engineer, engineering, backend, digital nomad
#
# Job #45
# Company Name : MailerLite
# Job Role     : Web Developer
# Location     :
# Tags/Features: front end, dev
#
# Job #46
# Company Name : Smartbug Media
# Job Role     : Account Strategist
# Location     : Remote, United States
# Tags/Features: strategist, support, growth, director, voice, strategy, management, lead, content, senior, operations, marketing, sales, health, recruiting, e-commerce
#
# Job #47
# Company Name : COMPLY
# Job Role     : Associate Customer Success Manager
# Location     : United States
# Tags/Features: manager, salesforce, consulting, technical, support, software, growth, financial, investment, leader, management, health
#
# Job #48
# Company Name : Panopto
# Job Role     : Account Executive Enterprise
# Location     : Remote - US
# Tags/Features: saas, technical, recruiter, support, manager, video, leader, management, senior, sales, health, recruitment, executive
#
# Job #49
# Company Name : Harkla
# Job Role     : Sales Development Representative
# Location     :
# Tags/Features: sales
#
# Job #50
# Company Name : AscendEX
# Job Role     : Senior Front End Engineer
# Location     :
# Tags/Features: design, cryptocurrency, front-end, back-end, software, growth, code, web, financial, management, senior, junior, engineer, engineering, digital nomad
#
# Job #51
# Company Name : Coin Market Cap Ltd
# Job Role     : Business Data Analyst
# Location     :
# Tags/Features: analyst, crypto, support, growth, web, financial, mobile, operational, analytics
#
# Job #52
# Company Name : Backpack
# Job Role     : Infrastructure
# Location     :
# Tags/Features: security, developer, cloud, engineering, digital nomad
#
# Job #53
# Company Name : Speechify
# Job Role     : Software Engineer Data Infrastructure & Acquisition
# Location     :
# Tags/Features: dev
#
# Job #54
# Company Name : Greenlight Financial Technology
# Job Role     : Software Engineer II Full Stack
# Location     : Atlanta (Remote Friendly)
# Tags/Features: software, design, technical, recruiter, support, web, finance, financial, fintech, banking, mobile, senior, reliability, health, engineer, engineering, backend, digital nomad
#
# Job #55
# Company Name : Right Side Up
# Job Role     : Associate Creative Director
# Location     : Austin, TX
# Tags/Features: director, design, financial, lead, junior, marketing, digital nomad
#
# Job #56
# Company Name : AFAR
# Job Role     : Revenue Operations Manager
# Location     : New York, NY
# Tags/Features: manager, design, support, growth, travel, finance, strategy, management, lead, operations, marketing, sales, digital nomad
#
# Job #57
# Company Name : Discern
# Job Role     : Fullstack Golang Engineer
# Location     :
# Tags/Features: golang, software, golang, engineer, fullstack
#
# Job #58
# Company Name : Tempesta Technologies
# Job Role     : C C++ Linux developer
# Location     :
# Tags/Features: linux, c plus plus, c, databases, algorithms, data structures
#
# Job #59
# Company Name : Melapress
# Job Role     : Content led Marketer
# Location     :
# Tags/Features: marketing, content writing, copywriting
#
# Job #60
# Company Name : Melapress
# Job Role     : WordPress Plugins & Themes developer
# Location     :
# Tags/Features: dev, devops, wordpress, php, javascript, full time, ecommerce, api, english
#
# Job #61
# Company Name : The Block
# Job Role     : Marketing Lead
# Location     : Remote within United States
# Tags/Features: web3, crypto, cryptocurrency, salesforce, support, growth, controller, voice, financial, strategy, lead, content, operations, marketing, legal, sales
#
# Job #62
# Company Name : Clipbook
# Job Role     : Intelligence &amp; Research Analyst
# Location     :
# Tags/Features: analyst, support, strategy, lead
#
# Job #63
# Company Name : Injective Labs
# Job Role     : Government Relations Officer
# Location     :
# Tags/Features: defi, crypto, technical, growth, financial, finance, leader, strategy, lead, operations, legal, educational, executive
#
# Job #64
# Company Name : Greenlight Financial Technology
# Job Role     : Software Engineer II Full Stack
# Location     : Atlanta (Remote Friendly)
# Tags/Features: software, design, technical, recruiter, support, web, finance, financial, fintech, banking, mobile, senior, reliability, health, engineer, engineering, backend, digital nomad
#
# Job #65
# Company Name : Crewvision
# Job Role     : UI UX Product Designer
# Location     :
# Tags/Features: design
#
# Job #66
# Company Name : Interaction Design Foundation
# Job Role     : Admin and Support Specialist With Love for Writing
# Location     :
# Tags/Features: content writing, customer support, writing
#
# Job #67
# Company Name : dLocal
# Job Role     : Crypto Compliance Project Manager
# Location     :
# Tags/Features: crypto, manager, cryptocurrency, support, financial, fintech, content, go, health, non tech
#
# Job #68
# Company Name : OANDA Europe Ltd.
# Job Role     : Head of CRM
# Location     : London
# Tags/Features: cryptocurrencies, support, software, growth, financial, strategy, management, lead, marketing, analytics, recruitment
#
# Job #69
# Company Name : Private.Ki
# Job Role     : Content Producer Technical Content Engineer Junior Dev
# Location     :
# Tags/Features: other, dev, writer, writing, marketing
#
# Job #70
# Company Name : Sword Health
# Job Role     : Executive Assistant &amp; Office Manager
# Location     : Lisboa
# Tags/Features: manager, assistant, support, growth, travel, financial, management, sales, medical, health, executive
#
# Job #71
# Company Name : Quantum Metric
# Job Role     : Account Executive Retail
# Location     : United States
# Tags/Features: saas, training, support, devops, financial, education, leader, android, sales, recruitment, executive, ecommerce
#
# Job #72
# Company Name : AllTrails
# Job Role     : Senior Product Designer
# Location     : Remote
# Tags/Features: design, ios, training, designer, testing, growth, web, lead, senior, marketing, engineering, digital nomad
#
# Job #73
# Company Name : CrowdGen by Appen
# Job Role     : Data Collection Participant Photo Submission Task
# Location     : Any
# Tags/Features: training, manager
#
# Job #74
# Company Name : Aprio
# Job Role     : Aprio PH FP&amp;A Analyst
# Location     : Clark, Pampanga
# Tags/Features: analyst, testing, growth, financial, finance, microsoft, management, senior, executive, full-time
#
# Job #75
# Company Name : Heard
# Job Role     : Sales Development Representative
# Location     : Remote
# Tags/Features: saas, consult, growth, voice, lead, excel, sales, health
#
# Job #76
# Company Name : Gravie
# Job Role     : Underwriter
# Location     : Remote
# Tags/Features: design, training, technical, support, growth, financial, education, strategy, management, sales, health, healthcare, digital nomad
#
# Job #77
# Company Name : Sensor Tower
# Job Role     : Full Stack Engineer
# Location     : Istanbul
# Tags/Features: jira, c#, developer, code, bank, analytics, health, engineer, recruitment, linux, full-time, digital nomad
#
# Job #78
# Company Name : Koombea
# Job Role     : Senior AI Python Developer
# Location     :
# Tags/Features: python, developer, software, api, senior, engineering, backend, digital nomad
#
# Job #79
# Company Name : Slate
# Job Role     : User Support Specialist
# Location     : Remote
# Tags/Features: technical, support, lead, content, engineering
#
# Job #80
# Company Name : Proof
# Job Role     : Senior Software Engineer
# Location     : Remote, Boston, MA Preferred
# Tags/Features: software, design, front-end, back-end, security, technical, support, growth, code, web, manager, cloud, ruby, rails, management, lead, senior, legal, go, engineer, engineering, digital nomad
#
# Job #81
# Company Name : Egen
# Job Role     : ML Scientist Foundation Model
# Location     : Remote, Central US
# Tags/Features: design, training, technical, support, cloud, legal, health, engineering, digital nomad
#
# Job #82
# Company Name : Coins.ph
# Job Role     : Exchange Operations Analyst
# Location     : Singapore, Singapore
# Tags/Features: analyst, crypto, cryptocurrencies, system, test, growth, financial, bank, admin, mobile, management, operations
#
# Job #83
# Company Name : Voxy Inc
# Job Role     : Customer Success Analyst
# Location     : SÃ£o Paulo
# Tags/Features: analyst, hr, students, training, consulting, technical, education, leader, management, health
#
# Job #84
# Company Name : City IT
# Job Role     : QA Analyst
# Location     : Any US State
# Tags/Features: analyst, system, support, software, testing, test, scrum, qa, management, go
#
# Job #85
# Company Name : Seaport Global Holdings LLC
# Job Role     : Investment Research Associate
# Location     : Flexible
# Tags/Features: accounting, investment, finance, senior, excel, non tech
#
# Job #86
# Company Name : HONK
# Job Role     : Technical Account Manager
# Location     : Remote
# Tags/Features: manager, design, saas, training, consulting, technical, support, operations, sales, engineering, digital nomad
#
# Job #87
# Company Name : The Block
# Job Role     : Sales Director
# Location     : Remote within United States
# Tags/Features: director, crypto, cryptocurrency, ceo, support, growth, voice, financial, video, lead, senior, operations, sales, executive
#
# Job #88
# Company Name : MachineFi Lab
# Job Role     : Developer Relations Engineer
# Location     : US Remote
# Tags/Features: developer, design, web3, crypto, cryptocurrency, technical, growth, code, travel, api, leader, marketing, engineer, engineering, digital nomad
#
# Job #89
# Company Name : Exora
# Job Role     : Assistant Trader
# Location     :
# Tags/Features: finance, sales, crypto, junior
#
# Job #90
# Company Name : Prompt
# Job Role     : Senior DevOps Engineer
# Location     :
# Tags/Features: design, system, security, docker, developer, software, devops, investment, cloud, management, senior, reliability, healthcare, engineer, digital nomad
#
# Job #91
# Company Name : Loft Orbital Solutions
# Job Role     : Senior Security Engineer
# Location     :
# Tags/Features: security, design, software, growth, code, financial, senior, operations, health, healthcare, engineer, engineering, digital nomad
#
# Job #92
# Company Name : FetLife
# Job Role     : Senior DevOps Engineer
# Location     :
# Tags/Features: engineer, sys admin, ops, ruby, devops, postgres, elasticsearch, docker, redis, rust, kubernetes, google cloud, site reliability engineer
#
# Job #93
# Company Name : RYZ Labs
# Job Role     : Manufacturing Experts AI Trainer
# Location     : Remote-
# Tags/Features: trainer, cloud
#
# Job #94
# Company Name : Management Leadership For Tomorrow
# Job Role     : Primary Coach Career Prep
# Location     : Remote
# Tags/Features: salesforce, students, consulting, founder, support, growth, travel, financial, leader, exec, management, content, legal, health, recruitment, internship, full-time, part-time
#
# Job #95
# Company Name : Tenderly
# Job Role     : Blockchain Security Researcher
# Location     : Europe OR In-Office Belgrade
# Tags/Features: security, web3, ethereum, full-stack, support, testing, growth, serverless, cloud, node, golang
#
#  Successfully scraped 95 job postings.
#
#  Data successfully saved to remoteok_jobs.csv
#
# --- Process Complete ---
